# %%
import pandas as pd

data = {
    "항목": ["유형", "내용", "원공시일", "공시일", "지정예고일", "지정일", "부과벌점", "공시위반제재금(원)", "공시책임자 등 교체요구 여부", "- 교체요구 대상", "- 교체사유", "최근 1년간 불성실공시법인 부과벌점(당해 부과벌점 포함)", "근거규정", "기타"],
    "내용": [
        "공시번복", 
        "유상증자결정(주주배정후 실권주 일반공모) 철회", 
        "2023-09-11", 
        "2024-02-20", 
        "2024-03-19", 
        "2024-04-15", 
        "0.0", 
        "14,000,000", 
        "미해당", 
        "-", 
        "-", 
        "0.0", 
        "코스닥시장 공시규정 제28조, 제32조 및 제34조", 
        "* 동사의 부과벌점은 3.5점이나, 이에 대하여 공시위반제재금 1,400만원(3.5점*400만원)을 대체부과\n* 공시위반제재금 납부기한은 부과통지일로부터 1월 이내이며, 제재금 미납시에는 가중벌점(제재금/400만원*1.2)이 부과될 수 있음"
    ]
}

df = pd.DataFrame(data)
display(df)
# Out:
#                                  항목  \
# 0                                유형
# 1                                내용
# 2                              원공시일
# 3                               공시일
# 4                             지정예고일
# 5                               지정일
# 6                              부과벌점
# 7                        공시위반제재금(원)
# 8                   공시책임자 등 교체요구 여부
# 9                         - 교체요구 대상
# 10                           - 교체사유
# 11  최근 1년간 불성실공시법인 부과벌점(당해 부과벌점 포함)
# 12                             근거규정
# 13                               기타
#
#                                                    내용
# 0                                                공시번복
# 1                           유상증자결정(주주배정후 실권주 일반공모) 철회
# 2                                          2023-09-11
# 3                                          2024-02-20
# 4                                          2024-03-19
# 5                                          2024-04-15
# ...
